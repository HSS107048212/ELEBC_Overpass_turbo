# %% [markdown]
# <a href="https://colab.research.google.com/github/HSS107048212/ELEBC_Overpass_turbo/blob/main/02_Read_data_of_Youbike2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Get data from GitHub
# !git clone https://github.com/HSS107048212/ELEBC_Overpass_turbo.git
# Out:
# Cloning into 'ELEBC_Overpass_turbo'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 5), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (24/24), 152.35 KiB | 5.44 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
import pandas as pd

# GitHub path to your JSON file
Youbike_json_path = "/content/ELEBC_Overpass_turbo/youbike_immediate.json"

# Read JSON file from GitHub path
data = pd.read_json(Youbike_json_path)

# Convert JSON data to DataFrame
df = pd.DataFrame(data)

df
# Out:
#             sno                       sna  tot  sbi   sarea  \
# 0     500101001        YouBike2.0_捷運科技大樓站   28    3     大安區
# 1     500101002    YouBike2.0_復興南路二段273號前   21    3     大安區
# 2     500101003      YouBike2.0_國北教大實小東側門   16    2     大安區
# 3     500101004         YouBike2.0_和平公園東側   11    0     大安區
# 4     500101005      YouBike2.0_辛亥復興路口西北側   16    3     大安區
# ...         ...                       ...  ...  ...     ...
# 1374  500119087      YouBike2.0_臺大總圖書館西南側   30   28  臺大公館校區
# 1375  500119088        YouBike2.0_臺大黑森林西側   20   20  臺大公館校區
# 1376  500119089        YouBike2.0_臺大獸醫館南側   24   18  臺大公館校區
# 1377  500119090      YouBike2.0_臺大新體育館東南側   40   28  臺大公館校區
# 1378  500119091  YouBike2.0_臺大明達館北側(員工宿舍)   18    4  臺大公館校區
#
#                      mday       lat        lng             ar     sareaen  \
# 0     2024-03-27 10:57:17  25.02605  121.54360    復興南路二段235號前  Daan Dist.
# 1     2024-03-27 10:54:16  25.02565  121.54357   復興南路二段273號西側  Daan Dist.
# ...

# %%
df.shape
# Out:
# (1379, 18)

# %%
df[["sna","tot","sarea","lat","lng"]]
# Out:
#                            sna  tot   sarea       lat        lng
# 0           YouBike2.0_捷運科技大樓站   28     大安區  25.02605  121.54360
# 1       YouBike2.0_復興南路二段273號前   21     大安區  25.02565  121.54357
# 2         YouBike2.0_國北教大實小東側門   16     大安區  25.02429  121.54124
# 3            YouBike2.0_和平公園東側   11     大安區  25.02351  121.54282
# 4         YouBike2.0_辛亥復興路口西北側   16     大安區  25.02153  121.54299
# ...                        ...  ...     ...       ...        ...
# 1374      YouBike2.0_臺大總圖書館西南側   30  臺大公館校區  25.01690  121.54031
# 1375        YouBike2.0_臺大黑森林西側   20  臺大公館校區  25.01995  121.54347
# 1376        YouBike2.0_臺大獸醫館南側   24  臺大公館校區  25.01791  121.54242
# 1377      YouBike2.0_臺大新體育館東南側   40  臺大公館校區  25.02112  121.53591
# 1378  YouBike2.0_臺大明達館北側(員工宿舍)   18  臺大公館校區  25.01816  121.54469
#
# [1379 rows x 5 columns]

# %%
df["sarea"].unique()
# Out:
# array(['大安區', '大同區', '士林區', '文山區', '中正區', '中山區', '內湖區', '北投區', '松山區',
#        '南港區', '信義區', '萬華區', '臺大公館校區'], dtype=object)

# %%
# 将 '臺大公館校區' 替换为 '大安區'
df['sarea'] = df['sarea'].replace('臺大公館校區', '大安區')
df["sarea"].unique()
# Out:
# array(['大安區', '大同區', '士林區', '文山區', '中正區', '中山區', '內湖區', '北投區', '松山區',
#        '南港區', '信義區', '萬華區'], dtype=object)
